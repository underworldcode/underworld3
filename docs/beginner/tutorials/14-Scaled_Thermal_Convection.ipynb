# %% [markdown]
# # Notebook 14: Scaled Thermal Convection
#
# This notebook demonstrates a complete thermal convection problem with non-dimensional scaling. We'll solve a coupled Stokes-temperature system with realistic mantle convection parameters.
#
# In this notebook you'll learn:
# - Setting up coupled Stokes and temperature equations
# - Computing buoyancy forces from temperature
# - Using realistic mantle convection parameters
# - Interpreting non-dimensional results in dimensional units
# - Understanding the Rayleigh number

# %%
import nest_asyncio

nest_asyncio.apply()

import os

os.environ["SYMPY_USE_CACHE"] = "no"

import numpy as np
import sympy
import underworld3 as uw

# %% [markdown]
# ## Problem Setup: Steady-State Thermal Convection
#
# We'll solve thermal convection in a square box with:
# - Hot bottom boundary (driving convection)
# - Cold top boundary
# - Free-slip walls
# - Incompressible Stokes flow
#
# The equations are:
# - **Stokes**: ∇·σ = -ρ₀αgT (buoyancy from temperature)
# - **Energy**: u·∇T = κ∇²T (steady-state, advection = diffusion)

# %% [markdown]
# ## Reference Quantities and Dimensional Parameters
#
# First, set up realistic mantle convection parameters and reference scales:

# %%
# Reset and get model
uw.reset_default_model()
model = uw.get_default_model()

# Realistic mantle parameters
model.set_reference_quantities(
    domain_depth=uw.quantity(2900, "km"),  # Mantle depth
    plate_velocity=uw.quantity(5, "cm/year"),  # Plate motion
    mantle_viscosity=uw.quantity(1e21, "Pa*s"),  # Mantle viscosity
    temperature_difference=uw.quantity(3000, "K"),  # ΔT across mantle
)

# Physical constants (dimensional)
rho0 = 3300 * uw.units("kg/m^3")  # Reference density
alpha = 3e-5 * uw.units("1/K")  # Thermal expansion
g = 10 * uw.units("m/s^2")  # Gravity
kappa = 1e-6 * uw.units("m^2/s")  # Thermal diffusivity

# Display parameters
rho0, alpha, g, kappa
# Out:
# (<Quantity(3300.0, 'kilogram / meter ** 3')>,
#  <Quantity(3e-05, '1 / kelvin')>,
#  <Quantity(10.0, 'meter / second ** 2')>,
#  <Quantity(1e-06, 'meter ** 2 / second')>)

# %% [markdown]
# ## Compute Rayleigh Number
#
# The Rayleigh number Ra characterizes the vigor of convection:
#
# Ra = (ρ₀ α g ΔT L³) / (η κ)
#
# Higher Ra means more vigorous convection.

# %%
rho0 = uw.expression(r"\rho_0", uw.quantity(3300, "kg/m^3"), "reference density")
alpha = uw.expression(r"\alpha", uw.quantity(3e-5, "1/K"), "thermal expansivity")
g = uw.expression(r"g", uw.quantity(9.8, "m/s/s"), "gravitational acceleration")
kappa = uw.expression(r"\kappa", uw.quantity(1e-6, "m^2/s"), "thermal diffusivity")
L0 = uw.expression(r"L_0", uw.quantity(2900, "km").to("m"), "reference length, mantle depth")
eta0 = uw.expression(r"\eta_0", uw.quantity(1e21, "Pa*s"), "Reference viscosity") 
DeltaT = uw.expression(r"\Delta T", uw.quantity(3000, "K"), "Temperature drop")

# Compute Rayleigh number: Ra = (ρ₀ α g ΔT L³) / (η κ)

Ra = uw.expression(r"\mathrm{Ra}", (rho0 * alpha * g * DeltaT * L0**3) / (eta0 * kappa), "Rayleigh number")

# %%
print(uw.unwrap(Ra, keep_constants=True))
# Out:
# 80.4837*\Delta T*\alpha*g/\kappa

# %%
print(kappa * alpha)
# Out:
# 1.0e-6*\alpha

# %% [markdown]
# This is a moderate Rayleigh number typical of Earth's mantle, producing steady convection cells.

# %% [markdown]
# ## Create Mesh and Variables
#
# Set up the computational domain and fields:

# %%
# Create mesh (non-dimensional coordinates 0 to 1)
resolution = 16
mesh = uw.meshing.StructuredQuadBox(
    elementRes=(resolution, resolution),
    minCoords=(0.0, 0.0),
    maxCoords=(1.0, 1.0),
    qdegree=3,
)

# Get coordinate symbols
x, y = mesh.X
# Out:
# Structured box element resolution 16 16

# %%
# Create variables with physical units
v = uw.discretisation.MeshVariable("v", mesh, 2, degree=2, units="m/s")
p = uw.discretisation.MeshVariable("p", mesh, 1, degree=1, units="Pa")
T = uw.discretisation.MeshVariable("T", mesh, 1, degree=2, units="K")

# Get scaling coefficients
V0_scale = v.scaling_coefficient
P0_scale = p.scaling_coefficient
T0_scale = T.scaling_coefficient

print(f"Velocity scale: {V0_scale:.3e} m/s")
print(f"Pressure scale: {P0_scale:.3e} Pa")
print(f"Temperature scale: {T0_scale:.3e} K")
# Out:
# Velocity scale: 1.584e-09 m/s
# Pressure scale: 5.463e+05 Pa
# Temperature scale: 3.000e+03 K

# %% [markdown]
# ## Enable Non-Dimensional Scaling

# %%
uw.use_nondimensional_scaling(True)

# %%
# Create Stokes solver
stokes = uw.systems.Stokes(mesh, velocityField=v, pressureField=p)
stokes.constitutive_model = uw.constitutive_models.ViscousFlowModel

# IMPORTANT: Since we have reference quantities defined, we must provide units
# for all constitutive model parameters. The viscosity is in the stress tensor: σ = 2ηε̇
# In dimensional form, η has units of Pa·s (pascal-seconds)
stokes.constitutive_model.Parameters.viscosity = uw.quantity(1e21, "Pa*s")

# Buoyancy force (ND form)
# In non-dimensional form: F̂ = -Ra·T̂ where Ra contains all physical constants
unit_y = sympy.Matrix([0, 1])
stokes.bodyforce = -Ra * T[0] * unit_y

# Boundary conditions: free slip on all walls
stokes.add_dirichlet_bc((0.0, sympy.oo), "Left")  # u_x = 0 on left (u_y free)
stokes.add_dirichlet_bc((0.0, sympy.oo), "Right")  # u_x = 0 on right (u_y free)
stokes.add_dirichlet_bc((sympy.oo, 0.0), "Top")  # u_y = 0 on top (u_x free)
stokes.add_dirichlet_bc((sympy.oo, 0.0), "Bottom")  # u_y = 0 on bottom (u_x free)

stokes
# Out:
# **Class**: <class 'underworld3.systems.solvers.SNES_Stokes'>
# # Underworld / PETSc General Saddle Point Equation Solver
# Primary problem:
# $\tiny \quad \nabla \cdot \color{Blue}\left[\begin{matrix}- { \hspace{ 0.002pt } {p} }(\mathbf{x}) + 2 { \hspace{ 0.002pt } {v} }_{ 0,0}(\mathbf{x}) & { \hspace{ 0.002pt } {v} }_{ 0,1}(\mathbf{x}) + { \hspace{ 0.002pt } {v} }_{ 1,0}(\mathbf{x})\\{ \hspace{ 0.002pt } {v} }_{ 0,1}(\mathbf{x}) + { \hspace{ 0.002pt } {v} }_{ 1,0}(\mathbf{x}) & - { \hspace{ 0.002pt } {p} }(\mathbf{x}) + 2 { \hspace{ 0.002pt } {v} }_{ 1,1}(\mathbf{x})\end{matrix}\right]$ +
# $\tiny \phantom{ \quad \nabla \cdot} \color{DarkRed}\left[\begin{matrix}0\\\frac{80.4837 { \hspace{ 0.002pt } {T} }(\mathbf{x}) \Delta T \alpha g}{\kappa}\end{matrix}\right]\color{Black} = 0 $
# Constraint:
# $\tiny \phantom{ \quad \nabla \cdot} \left[\begin{matrix}{ \hspace{ 0.002pt } {v} }_{ 0,0}(\mathbf{x}) + { \hspace{ 0.002pt } {v} }_{ 1,1}(\mathbf{x})\end{matrix}\right] = 0 $
# *Where:*
# $\quad$$\displaystyle \Delta T$$=$$\displaystyle 3000.0$
# $\quad$$\displaystyle \kappa$$=$$\displaystyle 1.0 \cdot 10^{-6}$
# $\quad$$\displaystyle \alpha$$=$$\displaystyle 3.0 \cdot 10^{-5}$
# $\quad$$\displaystyle g$$=$$\displaystyle 9.8$
# # Boundary Conditions
# | Type   | Boundary | Expression |
# |:------------------------ | -------- | ---------- |
# | **essential** | Left | $\left[\begin{matrix}0.0 & \infty\end{matrix}\right]  $ |
# | **essential** | Right | $\left[\begin{matrix}0.0 & \infty\end{matrix}\right]  $ |
# | **essential** | Top | $\left[\begin{matrix}\infty & 0.0\end{matrix}\right]  $ |
# | **essential** | Bottom | $\left[\begin{matrix}\infty & 0.0\end{matrix}\right]  $ |
# This solver is formulated as a 2 dimensional problem with a 2 dimensional mesh

# %%
# Temperature: T = (1 - y) + 0.1*cos(2πx)*sin(πy)
# This is in ND units (0 to 1), representing (T-T_cold)/ΔT
T_init = (1.0 - y) + 0.1 * sympy.cos(2 * np.pi * x) * sympy.sin(np.pi * y)

# Evaluate and assign
T.array[...] = uw.function.evaluate(T_init, T.coords).reshape(T.array.shape)

print(f"Initial temperature (ND): [{T.min():.3e}, {T.max():.3e}]")
# Out:
# Initial temperature (ND): [-7.401e-20 kelvin, 3.333e-04 kelvin]

# %%
# Create advection-diffusion solver
adv_diff = uw.systems.AdvDiffusionSLCN(
    mesh,
    u_Field=T,
    V_fn=v,
)

# Constitutive model for diffusion
# IMPORTANT: Since we have reference quantities defined, we must provide units
# for all parameters. The diffusivity is in the flux: flux = -κ∇T
# In dimensional form, κ has units of m²/s (thermal diffusivity)
adv_diff.constitutive_model = uw.constitutive_models.DiffusionModel
adv_diff.constitutive_model.Parameters.diffusivity = uw.quantity(1e-6, "m^2/s")

# Temperature boundary conditions
# These are non-dimensional (ND values between 0 and 1)
adv_diff.add_dirichlet_bc(1.0, "Bottom")  # Hot bottom (T̂ = 1)
adv_diff.add_dirichlet_bc(0.0, "Top")  # Cold top (T̂ = 0)

adv_diff
# Out:
# **Class**: <class 'underworld3.systems.solvers.SNES_AdvectionDiffusion'>
# # Underworld / PETSc General Scalar Equation Solver
# Primary problem:
# $\tiny \quad \nabla \cdot \color{Blue}\left[\begin{matrix}\frac{{ \hspace{ 0.002pt } {T} }_{,0}(\mathbf{x})}{2} + \frac{{ \hspace{ 0.002pt } {{ {F[ { \hspace{ 0.002pt } {T} } ] }^{ * } }} }_{ 0 }(\mathbf{x})}{2} & \frac{{ \hspace{ 0.002pt } {T} }_{,1}(\mathbf{x})}{2} + \frac{{ \hspace{ 0.002pt } {{ {F[ { \hspace{ 0.002pt } {T} } ] }^{ * } }} }_{ 1 }(\mathbf{x})}{2}\end{matrix}\right]$ +
# $\tiny \phantom{ \quad \nabla \cdot} \color{DarkRed}\left[\begin{matrix}\frac{{ \hspace{ 0.002pt } {T} }(\mathbf{x}) - { \hspace{ 0.002pt } {{ { \hspace{ 0.002pt } {T} }^{ * } }} }(\mathbf{x})}{\Delta t}\end{matrix}\right]\color{Black} = 0 $
# *Where:*
# $\quad$$\displaystyle \Delta t$$=$$\displaystyle 0$
# # Boundary Conditions
# | Type   | Boundary | Expression |
# |:------------------------ | -------- | ---------- |
# | **essential** | Bottom | $\left[\begin{matrix}0.000333333333333333\end{matrix}\right]  $ |
# | **essential** | Top | $\left[\begin{matrix}0.0\end{matrix}\right]  $ |
# This solver is formulated as a 2 dimensional problem with a 2 dimensional mesh
# $\quad\mathrm{u} = $ $\displaystyle \left[\begin{matrix}{ \hspace{ 0.002pt } {T} }(\mathbf{x})\end{matrix}\right]$
# $\quad\mathbf{v} = $ $\displaystyle \left[\begin{matrix}{ \hspace{ 0.002pt } {v} }_{ 0 }(\mathbf{x}) & { \hspace{ 0.002pt } {v} }_{ 1 }(\mathbf{x})\end{matrix}\right]$
# $\quad\Delta t = $ $\displaystyle \Delta t$

# %%
# Create Stokes solver
stokes = uw.systems.Stokes(mesh, velocityField=v, pressureField=p)
stokes.constitutive_model = uw.constitutive_models.ViscousFlowModel

# IMPORTANT: Since we have reference quantities defined, we must provide units
# for all constitutive model parameters. The viscosity is in the stress tensor: σ = 2ηε̇
# In dimensional form, η has units of Pa·s (pascal-seconds)
stokes.constitutive_model.Parameters.viscosity = uw.quantity(1e21, "Pa*s")

# Buoyancy force (ND form)
# In non-dimensional form: F̂ = -Ra·T̂ where Ra contains all physical constants
unit_y = sympy.Matrix([0, 1])
stokes.bodyforce = -Ra * T[0] * unit_y

# Boundary conditions: free slip on all walls
stokes.add_dirichlet_bc((0.0, sympy.oo), "Left")  # u_x = 0 on left (u_y free)
stokes.add_dirichlet_bc((0.0, sympy.oo), "Right")  # u_x = 0 on right (u_y free)
stokes.add_dirichlet_bc((sympy.oo, 0.0), "Top")  # u_y = 0 on top (u_x free)
stokes.add_dirichlet_bc((sympy.oo, 0.0), "Bottom")  # u_y = 0 on bottom (u_x free)

stokes
# Out:
# **Class**: <class 'underworld3.systems.solvers.SNES_Stokes'>
# # Underworld / PETSc General Saddle Point Equation Solver
# Primary problem:
# $\tiny \quad \nabla \cdot \color{Blue}\left[\begin{matrix}- { \hspace{ 0.002pt } {p} }(\mathbf{x}) + 2 { \hspace{ 0.002pt } {v} }_{ 0,0}(\mathbf{x}) & { \hspace{ 0.002pt } {v} }_{ 0,1}(\mathbf{x}) + { \hspace{ 0.002pt } {v} }_{ 1,0}(\mathbf{x})\\{ \hspace{ 0.002pt } {v} }_{ 0,1}(\mathbf{x}) + { \hspace{ 0.002pt } {v} }_{ 1,0}(\mathbf{x}) & - { \hspace{ 0.002pt } {p} }(\mathbf{x}) + 2 { \hspace{ 0.002pt } {v} }_{ 1,1}(\mathbf{x})\end{matrix}\right]$ +
# $\tiny \phantom{ \quad \nabla \cdot} \color{DarkRed}\left[\begin{matrix}0\\\frac{80.4837 { \hspace{ 0.002pt } {T} }(\mathbf{x}) \Delta T \alpha g}{\kappa}\end{matrix}\right]\color{Black} = 0 $
# Constraint:
# $\tiny \phantom{ \quad \nabla \cdot} \left[\begin{matrix}{ \hspace{ 0.002pt } {v} }_{ 0,0}(\mathbf{x}) + { \hspace{ 0.002pt } {v} }_{ 1,1}(\mathbf{x})\end{matrix}\right] = 0 $
# *Where:*
# $\quad$$\displaystyle \Delta T$$=$$\displaystyle 3000.0$
# $\quad$$\displaystyle \kappa$$=$$\displaystyle 1.0 \cdot 10^{-6}$
# $\quad$$\displaystyle \alpha$$=$$\displaystyle 3.0 \cdot 10^{-5}$
# $\quad$$\displaystyle g$$=$$\displaystyle 9.8$
# # Boundary Conditions
# | Type   | Boundary | Expression |
# |:------------------------ | -------- | ---------- |
# | **essential** | Left | $\left[\begin{matrix}0.0 & \infty\end{matrix}\right]  $ |
# | **essential** | Right | $\left[\begin{matrix}0.0 & \infty\end{matrix}\right]  $ |
# | **essential** | Top | $\left[\begin{matrix}\infty & 0.0\end{matrix}\right]  $ |
# | **essential** | Bottom | $\left[\begin{matrix}\infty & 0.0\end{matrix}\right]  $ |
# This solver is formulated as a 2 dimensional problem with a 2 dimensional mesh

# %%
display(sympy.Matrix((Ra*v[0], Ra*v[1])))
# Out:
# Matrix([
# [80.4837*\Delta T*\alpha*g*{ \hspace{ 0.002pt } {v} }_{ 0 }(N.x, N.y)/\kappa],
# [80.4837*\Delta T*\alpha*g*{ \hspace{ 0.002pt } {v} }_{ 1 }(N.x, N.y)/\kappa]])

# %%
print((2 * Ra) * v / 2)
# Out:
# Matrix([[80.4837*\Delta T*\alpha*g*{ \hspace{ 0.002pt } {v} }_{ 0 }(N.x, N.y)/\kappa, 80.4837*\Delta T*\alpha*g*{ \hspace{ 0.002pt } {v} }_{ 1 }(N.x, N.y)/\kappa]])

# %%
Ra.sym * v
# Out:
# Matrix([[80.4837*\Delta T*\alpha*g*{ \hspace{ 0.002pt } {v} }_{ 0 }(N.x, N.y)/\kappa, 80.4837*\Delta T*\alpha*g*{ \hspace{ 0.002pt } {v} }_{ 1 }(N.x, N.y)/\kappa]])

# %% [markdown]
# ## Set Up Temperature Solver
#
# For steady-state, we solve the advection-diffusion balance:
#
# v·∇T = κ∇²T
#
# In ND form with Péclet number Pe = VL/κ:
#
# v̂·∇̂T̂ = ∇̂²T̂

# %%
# Create advection-diffusion solver
adv_diff = uw.systems.AdvDiffusionSLCN(
    mesh,
    u_Field=T,
    V_fn=v,
)

# Constitutive model for diffusion
# IMPORTANT: Since we have reference quantities defined, we must provide units
# for all parameters. The diffusivity is in the flux: flux = -κ∇T
# In dimensional form, κ has units of m²/s (thermal diffusivity)
adv_diff.constitutive_model = uw.constitutive_models.DiffusionModel
adv_diff.constitutive_model.Parameters.diffusivity = uw.quantity(1e-6, "m^2/s")

# Temperature boundary conditions
# These are non-dimensional (ND values between 0 and 1)
adv_diff.add_dirichlet_bc(1.0, "Bottom")  # Hot bottom (T̂ = 1)
adv_diff.add_dirichlet_bc(0.0, "Top")  # Cold top (T̂ = 0)

adv_diff
# Out:
# **Class**: <class 'underworld3.systems.solvers.SNES_AdvectionDiffusion'>
# # Underworld / PETSc General Scalar Equation Solver
# Primary problem:
# $\tiny \quad \nabla \cdot \color{Blue}\left[\begin{matrix}\frac{{ \hspace{ 0.002pt } {T} }_{,0}(\mathbf{x})}{2} + \frac{{ \hspace{ 0.002pt } {{ {F[ { \hspace{ 0.002pt } {T} } ] }^{ * } }} }_{ 0 }(\mathbf{x})}{2} & \frac{{ \hspace{ 0.002pt } {T} }_{,1}(\mathbf{x})}{2} + \frac{{ \hspace{ 0.002pt } {{ {F[ { \hspace{ 0.002pt } {T} } ] }^{ * } }} }_{ 1 }(\mathbf{x})}{2}\end{matrix}\right]$ +
# $\tiny \phantom{ \quad \nabla \cdot} \color{DarkRed}\left[\begin{matrix}\frac{{ \hspace{ 0.002pt } {T} }(\mathbf{x}) - { \hspace{ 0.002pt } {{ { \hspace{ 0.002pt } {T} }^{ * } }} }(\mathbf{x})}{{ \Delta t \hspace{ 0.0029pt } }}\end{matrix}\right]\color{Black} = 0 $
# *Where:*
# $\quad$$\displaystyle \Delta t$$=$$\displaystyle 0$
# # Boundary Conditions
# | Type   | Boundary | Expression |
# |:------------------------ | -------- | ---------- |
# | **essential** | Bottom | $\left[\begin{matrix}0.000333333333333333\end{matrix}\right]  $ |
# | **essential** | Top | $\left[\begin{matrix}0.0\end{matrix}\right]  $ |
# This solver is formulated as a 2 dimensional problem with a 2 dimensional mesh
# $\quad\mathrm{u} = $ $\displaystyle \left[\begin{matrix}{ \hspace{ 0.002pt } {T} }(\mathbf{x})\end{matrix}\right]$
# $\quad\mathbf{v} = $ $\displaystyle \left[\begin{matrix}{ \hspace{ 0.002pt } {v} }_{ 0 }(\mathbf{x}) & { \hspace{ 0.002pt } {v} }_{ 1 }(\mathbf{x})\end{matrix}\right]$
# $\quad\Delta t = $ $\displaystyle \Delta t$

# %% [markdown]
# ## Solve Coupled System Iteratively
#
# Since temperature affects velocity (buoyancy) and velocity affects temperature (advection), we iterate:
#
# 1. Solve Stokes for velocity (given temperature)
# 2. Solve temperature equation (given velocity)
# 3. Repeat until convergence

# %%
stokes.solve()

# %%
dt = stokes.estimate_dt()

# %%
model.get_fundamental_scales()
# Out:
# {'length': <Quantity(2900000.0, 'meter')>,
#  'temperature': <Quantity(3000.0, 'kelvin')>,
#  'time': <Quantity(1.8303408e+15, 'second')>,
#  'mass': <Quantity(5.30798832e+42, 'kilogram')>}

# %%
adv_diff.solve(timestep=uw.quantity(1e7, "year"))
# Out:
# [0]PETSC ERROR: --------------------- Error Message --------------------------------------------------------------
# [0]PETSC ERROR: PETSc has generated inconsistent data
# [0]PETSC ERROR: Point 0: -1.42085e+10 1.40692e+10 0. not located in mesh
# [0]PETSC ERROR: WARNING! There are unused option(s) set! Could be the program crashed before usage or a spelling mistake, etc!
# [0]PETSC ERROR:   Option left: name:-dm_plex_hash_location (no value) source: code
# [0]PETSC ERROR:   Option left: name:-f value: /Users/lmoresi/Library/Jupyter/runtime/kernel-e8483652-1667-4ccf-81f4-37aa866346d8.json source: command line
# [0]PETSC ERROR:   Option left: name:-options_left value: 0 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_108_mg_levels_ksp_converged_maxits (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_108_mg_levels_ksp_max_it value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_108_pc_mg_type value: additive source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_ksp_rtol value: 0.001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_ksp_type value: gmres source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_mg_levels_ksp_converged_maxits (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_mg_levels_ksp_max_it value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_pc_gamg_agg_nsmooths value: 2 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_pc_gamg_repartition value: true source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_pc_gamg_type value: agg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_pc_mg_type value: additive source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_pc_type value: gamg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_snes_rtol value: 0.001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_149_snes_type value: newtonls source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_pressure_ksp_rtol value: 0.0001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_pressure_ksp_type value: fgmres source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_pressure_pc_type value: gasm source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_ksp_rtol value: 1e-05 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_ksp_type value: cg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_mg_levels_ksp_converged_maxits (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_mg_levels_ksp_max_it value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_pc_gamg_agg_nsmooths value: 2 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_pc_gamg_repartition value: true source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_pc_gamg_type value: agg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_pc_mg_type value: additive source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_fieldsplit_velocity_pc_type value: gamg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_pc_fieldsplit_diag_use_amat (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_pc_fieldsplit_off_diag_use_amat (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_pc_fieldsplit_schur_fact_type value: full source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_pc_fieldsplit_schur_precondition value: a11 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_pc_fieldsplit_type value: schur source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_pc_type value: fieldsplit source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_snes_ksp_ew (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_snes_ksp_ew_version value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_24_snes_rtol value: 0.0001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_ksp_type value: gmres source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_mg_levels_ksp_converged_maxits (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_mg_levels_ksp_max_it value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_pc_gamg_agg_nsmooths value: 2 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_pc_gamg_repartition value: true source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_pc_gamg_type value: agg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_pc_mg_type value: additive source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_pc_type value: gamg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_snes_rtol value: 0.0001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_38_snes_type value: newtonls source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_ksp_type value: gmres source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_mg_levels_ksp_converged_maxits (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_mg_levels_ksp_max_it value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_pc_gamg_agg_nsmooths value: 2 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_pc_gamg_repartition value: true source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_pc_gamg_type value: agg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_pc_mg_type value: additive source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_pc_type value: gamg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_snes_rtol value: 0.0001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_59_snes_type value: newtonls source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_ksp_rtol value: 0.001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_ksp_type value: gmres source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_mg_levels_ksp_converged_maxits (no value) source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_mg_levels_ksp_max_it value: 3 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_pc_gamg_agg_nsmooths value: 2 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_pc_gamg_repartition value: true source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_pc_gamg_type value: agg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_pc_mg_type value: additive source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_pc_type value: gamg source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_snes_rtol value: 0.001 source: code
# [0]PETSC ERROR:   Option left: name:-Solver_79_snes_type value: newtonls source: code
# [0]PETSC ERROR: See https://petsc.org/release/faq/ for trouble shooting.
# [0]PETSC ERROR: PETSc Release Version 3.23.4, unknown
# [0]PETSC ERROR: /Users/lmoresi/+Underworld/underworld-pixi-2/.pixi/envs/default/lib/python3.12/site-packages/ipykernel_launcher.py with 1 MPI process(es) and PETSC_ARCH petsc-4-uw on Wombat.local by lmoresi Wed Oct 29 20:29:20 2025
# [0]PETSC ERROR: Configure options: --download-bison --download-eigen=1 --download-hdf5=0 --download-metis=1 --download-mmg --download-mpi4py=0 --download-mpich=0 --download-mumps=1 --download-parmetis=1 --download-parmmg --download-pragmatic=1 --download-ptscotch --download-scalapack --download-slepc --with-debugging=0 --with-hdf5-dir=../.pixi/envs/default --with-hdf5=1 --with-mpi-dir=../.pixi/envs/default --with-petsc4py=0 --with-pragmatic=1 --with-x=0 PETSC_ARCH=petsc-4-uw
# [0]PETSC ERROR: #1 DMInterpolationSetUp_UW() at src/underworld3/function/petsc_tools.c:113
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 adv_diff.solve(timestep=uw.quantity(1e7, "year"))
#
# File ~/+Underworld/underworld-pixi-2/.pixi/envs/default/lib/python3.12/site-packages/underworld3/systems/solvers.py:1534, in SNES_AdvectionDiffusion.solve(self, zero_init_guess, timestep, _force_setup, _evalf, verbose)
#    1529     self._setup_solver(verbose)
#    1531 # Update History / Flux History terms
#    1532 # SemiLagrange and Lagrange may have different sequencing.
# -> 1534 self.DuDt.update_pre_solve(timestep, verbose=verbose, evalf=_evalf)
#    1535 self.DFDt.update_pre_solve(timestep, verbose=verbose, evalf=_evalf)
#    1537 super().solve(zero_init_guess, _force_setup)
#
# File ~/+Underworld/underworld-pixi-2/.pixi/envs/default/lib/python3.12/site-packages/underworld3/systems/ddt.py:736, in SemiLagrangian.update_pre_solve(self, dt, evalf, verbose, dt_physical)
#     732     v_at_node_pts_magnitude = v_at_node_pts
#     734 mid_pt_coords = coords_magnitude - 0.5 * dt * v_at_node_pts_magnitude
# --> 736 v_at_mid_pts = uw.function.global_evaluate(
#     737     self.V_fn,
#     738     mid_pt_coords,
#     739 )[:, 0, :]
#     741 # Extract magnitude from mid-point velocities if they have units
#     742 if hasattr(v_at_mid_pts, "magnitude"):
#
# File ~/+Underworld/underworld-pixi-2/.pixi/envs/default/lib/python3.12/site-packages/underworld3/function/__init__.py:133, in global_evaluate(expr, coords, coord_sys, other_arguments, simplify, verbose, evalf, rbf, data_layout, check_extrapolated)
#     130 import numpy as np
#     132 # Call the original Cython implementation with all parameters
# --> 133 raw_result = _global_evaluate_original(
#     134     expr,
#     135     coords=coords,
#     136     coord_sys=coord_sys,
#     137     other_arguments=other_arguments,
#     138     simplify=simplify,
#     139     verbose=verbose,
#     140     evalf=evalf,
#     141     rbf=rbf,
#     142     data_layout=data_layout,
#     143     check_extrapolated=check_extrapolated,
#     144 )
#     146 # Try to get units from the expression
#     147 result_units = get_units(expr)
#
# File src/underworld3/function/_function.pyx:377, in underworld3.function._function.global_evaluate()
#
# File src/underworld3/function/_function.pyx:469, in underworld3.function._function.evaluate()
#
# File src/underworld3/function/_function.pyx:768, in underworld3.function._function.petsc_interpolate()
#
# File src/underworld3/function/_function.pyx:731, in underworld3.function._function.petsc_interpolate.interpolate_vars_on_mesh()
#
# RuntimeError: Error encountered when trying to interpolate mesh variable.
# Interpolation location is possibly outside the domain.

# %%
for iteration in range(10):
    # Solve Stokes (velocity from temperature)
    stokes.solve()

    # Solve temperature (steady-state with current velocity)
    # For steady-state, use a large time step to reach equilibrium
    adv_diff.solve(timestep=uw.quantity(1e9, "year"))

    # Check velocity magnitude
    # Note: v.max() returns tuple (vx_max, vy_max) for vector variables
    v_max_nd = max(v.max().to_non)  # Get largest component
    if iteration % 2 == 0:
        print(f"Iteration {iteration}: max velocity (ND) = {v_max_nd:.3e}")

print("\nConverged solution")

# %%
uw.non_dimensionalise(v.max())

# %% [markdown]
# ## Examine Non-Dimensional Results
#
# The solution is stored in ND form. Let's look at the ND values:

# %%
# Non-dimensional values (order one, well-conditioned)
# Note: For vector variables, .max() returns tuple (vx_max, vy_max)
v_min_components = v.min()  # Tuple: (vx_min, vy_min)
v_max_components = v.max()  # Tuple: (vx_max, vy_max)

print("Non-dimensional values:")
print(f"  Velocity x-component: [{v_min_components[0]:.3e}, {v_max_components[0]:.3e}]")
print(f"  Velocity y-component: [{v_min_components[1]:.3e}, {v_max_components[1]:.3e}]")
print(f"  Temperature: [{T.min():.3e}, {T.max():.3e}]")

# %% [markdown]
# Notice all values are order-one. This is the benefit of ND scaling - PETSc worked with well-conditioned matrices.

# %% [markdown]
# ## Interpret in Dimensional Units
#
# To get physical values, we need to:
# 1. Multiply ND values by scaling coefficients
# 2. Wrap in `uw.quantity()` to attach units
# 3. Then convert to desired units

# %%
# Get maximum velocity component (ND value is plain float)
v_max_nd = max(v.max())

# Create dimensional Pint quantity
# Note: scaling_coefficient is a plain float, need to wrap with units
v_dimensional = uw.quantity(v_max_nd * V0_scale, "m/s")

# Now can convert units
v_cm_per_year = v_dimensional.to("cm/year")
v_mm_per_year = v_dimensional.to("mm/year")

print(f"Maximum velocity:")
print(f"  {v_cm_per_year:.2f}")
print(f"  {v_mm_per_year:.2f}")

# %% [markdown]
# The convection velocities are on the order of centimeters per year, similar to tectonic plate velocities!

# %%
# Temperature in Kelvin
# Scalars are simpler - .min()/.max() return plain floats
T_dimensional_min = uw.quantity(T.min() * T0_scale, "K")
T_dimensional_max = uw.quantity(T.max() * T0_scale, "K")

print(f"Temperature range:")
print(f"  {T_dimensional_min:.1f}")
print(f"  {T_dimensional_max:.1f}")

# %% [markdown]
# ## Compute Derived Quantities
#
# We can compute other physically meaningful quantities from the solution:

# %%
# Create variable for strain rate magnitude
strain_rate = uw.discretisation.MeshVariable("eps", mesh, 1, degree=1, units="1/s")

# Compute strain rate: ε̇ = √(½ε̇ᵢⱼε̇ᵢⱼ) where ε̇ᵢⱼ = ½(∂vᵢ/∂xⱼ + ∂vⱼ/∂xᵢ)
strain_rate_tensor = 0.5 * (v.diff(x) + v.diff(y).T)
strain_rate_expr = sympy.sqrt(
    0.5
    * (
        strain_rate_tensor[0, 0] ** 2
        + strain_rate_tensor[1, 1] ** 2
        + 2 * strain_rate_tensor[0, 1] ** 2
    )
)

# Project to mesh variable
proj = uw.systems.Projection(mesh, strain_rate)
proj.uw_function = strain_rate_expr
proj.solve()

print(f"Strain rate (ND): [{strain_rate.min():.3e}, {strain_rate.max():.3e}]")

# %%
# Convert to dimensional units
eps0_scale = strain_rate.scaling_coefficient
strain_rate_dimensional = uw.quantity(strain_rate.max() * eps0_scale, "1/s")

# Convert to common geological units
strain_rate_per_year = strain_rate_dimensional.to("1/year")

print(f"Maximum strain rate: {strain_rate_per_year:.3e}")

# %% [markdown]
# ## Summary
#
# We successfully solved a thermal convection problem with non-dimensional scaling:
#
# **Setup:**
# - Set realistic mantle reference quantities
# - Created variables with physical units
# - Enabled ND scaling
#
# **Physics:**
# - Rayleigh number Ra ≈ 10⁷ (moderate convection)
# - Coupled Stokes flow with temperature-dependent buoyancy
# - Steady-state advection-diffusion balance
#
# **Results:**
# - PETSc worked with order-one ND values (good conditioning)
# - Dimensional interpretation via scaling coefficients
# - Velocities ~cm/year (realistic for mantle convection)
# - Strain rates ~10⁻¹⁵ /s (typical geological rates)
#
# ### Key Insights
#
# 1. **Rayleigh Number**: The dimensionless parameter controlling convection vigor
# 2. **Buoyancy Scaling**: In ND form, F̂ = -Ra·T̂
# 3. **Coupled Systems**: Iterative solution for temperature-velocity coupling
# 4. **Dimensional Interpretation**: Use `uw.quantity(value * scale, units)` for unit conversion
# 5. **Vector Variables**: `.max()` returns tuple - use `max(v.max())` for largest component
#
# ### What's Next?
#
# To extend this example:
# - Add time evolution (time-dependent convection)
# - Include viscosity variations (temperature-dependent rheology)
# - Add internal heating (radioactive decay)
# - Explore different boundary conditions
# - Compute Nusselt number (heat flux efficiency)
