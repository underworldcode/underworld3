# %%
# to fix trame issue
import nest_asyncio
nest_asyncio.apply()

# %%
import sympy
import underworld3 as uw
import numpy as np
import os 
import mpi4py

os.environ["UW_TIMING_ENABLE"] = "1"
os.environ["UW_JITNAME"] = "TESTF"

# These are tested by test_001_meshes.py

mesh = uw.meshing.UnstructuredSimplexBox(
    cellSize=0.1, regular=True, qdegree=2, refinement=0
)

if mesh.dim == 2:
    x, y = mesh.X
else:
    x, y, z = mesh.X

u = uw.discretisation.MeshVariable("U", mesh, mesh.dim, 
                                   vtype=uw.VarType.VECTOR, 
                                   degree=2, varsymbol=r"\mathbf{u}",
)
p = uw.discretisation.MeshVariable("P",
    mesh, 1, vtype=uw.VarType.SCALAR, degree=1, continuous=True, 
                                   varsymbol=r"\mathbf{p}", 
)

stokes = uw.systems.Stokes(mesh, velocityField=u, pressureField=p, verbose=True)
stokes.constitutive_model = (
    uw.constitutive_models.ViscoElasticPlasticFlowModel
)
stokes.constitutive_model.Parameters.shear_viscosity_0 = 1

stokes.petsc_options["snes_type"] = "newtonls"
stokes.petsc_options["ksp_type"] = "fgmres"
stokes.petsc_options["ksp_monitor"] = None
stokes.petsc_options["snes_monitor"] = None
stokes.tolerance = 1.0e-3

# stokes.petsc_options.setValue("fieldsplit_velocity_pc_type", "mg")
stokes.petsc_options.setValue("fieldsplit_velocity_pc_mg_type", "kaskade")
stokes.petsc_options.setValue("fieldsplit_velocity_pc_mg_cycle_type", "w")

stokes.petsc_options["fieldsplit_velocity_mg_coarse_pc_type"] = "svd"
stokes.petsc_options[f"fieldsplit_velocity_ksp_type"] = "fcg"
stokes.petsc_options[f"fieldsplit_velocity_mg_levels_ksp_type"] = "chebyshev"
stokes.petsc_options[f"fieldsplit_velocity_mg_levels_ksp_max_it"] = 7
stokes.petsc_options[f"fieldsplit_velocity_mg_levels_ksp_converged_maxits"] = None

stokes.petsc_options.setValue("fieldsplit_pressure_pc_type", "gamg")
stokes.petsc_options.setValue("fieldsplit_pressure_pc_mg_type", "multiplicative")
stokes.petsc_options.setValue("fieldsplit_pressure_pc_mg_cycle_type", "v")

if mesh.dim == 2:
    stokes.bodyforce = sympy.Matrix([0.0, 1.0*sympy.sin(x)])

    stokes.add_natural_bc((0.0, -u[1].sym), "Top")
    # stokes.add_dirichlet_bc((sympy.oo, 0.0), "Top")
    stokes.add_dirichlet_bc((sympy.oo,0.0), "Bottom")
    stokes.add_dirichlet_bc((0.0,sympy.oo), "Left")
    stokes.add_dirichlet_bc((0.0,sympy.oo), "Right")

else:
    stokes.bodyforce = sympy.Matrix([0, sympy.sin(x), 0])

    stokes.add_essential_bc([0.0, 0.0, 0.0], "Top")
    stokes.add_essential_bc([0.0, 0.0, 0.0], "Bottom")
    stokes.add_essential_bc([0.0, 0.0, 0.0], "Left")
    stokes.add_essential_bc([0.0, 0.0, 0.0], "Right")    
    stokes.add_essential_bc([0.0, 0.0, 0.0], "Front")
    stokes.add_essential_bc([0.0, 0.0, 0.0], "Back")

# %%
with uw.utilities.CaptureStdout(split=False) as captured_dm_view:
    mesh.dm.view()

# %%
stokes.solve(verbose=False, debug=False)
stokes.dm.ds.view()

## assert stokes.snes.getConvergedReason() > 0
# Out:
# Stokes: Jacobians complete, now compile
# Setting bc 0 (natural)
#  - component: [0 1]
#  - boundary:   Top
#  - fn:         Matrix([[0], [-\mathbf{u}_{ 1 }(N.x, N.y)]])
# Setting bc 0 (essential)
#  - component: [1]
#  - boundary:   Bottom
#  - fn:         Matrix([[oo], [0]])
# Setting bc 1 (essential)
#  - component: [0]
#  - boundary:   Left
#  - fn:         Matrix([[0], [oo]])
# Setting bc 2 (essential)
#  - component: [0]
#  - boundary:   Right
#  - fn:         Matrix([[0], [oo]])
#   0 SNES Function norm 2.942451402048e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 2.942451402048e-02
#     1 KSP Residual norm 1.238283182747e-06
#     2 KSP Residual norm 3.281927123375e-10
#   1 SNES Function norm 4.473251006544e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 4.473251006544e-03
#     1 KSP Residual norm 3.806036941718e-07
#     2 KSP Residual norm 7.041457696798e-12
#   2 SNES Function norm 6.929441772867e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 6.929441772867e-04
#     1 KSP Residual norm 5.969136102330e-08
#     2 KSP Residual norm 1.075243755648e-12
#   3 SNES Function norm 1.073479379993e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.073479379993e-04
#     1 KSP Residual norm 9.300696500205e-09
#     2 KSP Residual norm 1.666506420329e-13
#   4 SNES Function norm 1.662971813832e-05
# Nonlinear  solve converged due to CONVERGED_FNORM_RELATIVE iterations 4
# Discrete System with 2 fields
#     cell total dim 15 total comp 3
#   Field velocity FEM 2 components (implicit) (Nq 6 Nqc 1) 1-jet
#     PetscFE Object: velocity (private__u_) 1 MPI process
#       type: vector
#       Vector Finite Element in 2 dimensions with 2 components
#       PetscSpace Object: P2 (private__u_) 1 MPI process
#         type: sum
#         Space in 2 variables with 2 components, size 12
#         Sum space of 2 concatenated subspaces (all identical)
#           PetscSpace Object: P2 (private__u_sumcomp_) 1 MPI process
#             type: poly
#             Space in 2 variables with 1 components, size 6
#             Polynomial space of degree 2
#       PetscDualSpace Object: P2 (private__u_) 1 MPI process
#         type: sum
#         Dual space with 2 components, size 12
#         Sum dual space of 2 concatenated subspaces (all identical)
#           PetscDualSpace Object: P2 1 MPI process
#             type: lagrange
#             Dual space with 1 components, size 6
#             Continuous Lagrange dual space
#         Quadrature on a triangle of order 4 on 6 points (dim 2)
#     Boundary Top[0 1] (Top) NATURAL_FIELD
#       components: 0, 1
#       values: 12
#     Weak Form System with 2 fields
#       boundary_residual_f0
#         (Top, 12) (0, 0) FUNC_0_petsc_eqn_17
#       boundary_jacobian_g0
#         (Top, 12) (0, 0) FUNC_0_petsc_eqn_18
#       boundary_jacobian_g1
#         (Top, 12) (0, 0) FUNC_0_petsc_eqn_19
#       boundary_jacobian_preconditioner_g0
#         (Top, 12) (0, 0) FUNC_0_petsc_eqn_18
#       boundary_jacobian_preconditioner_g1
#         (Top, 12) (0, 0) FUNC_0_petsc_eqn_19
#     Boundary Bottom[1] (Bottom) ESSENTIAL_FIELD
#       components: 1
#       values: 11
#       func: FUNC_0_petsc_eqn_3
#     Weak Form System with 2 fields
#     Boundary Left[0] (Left) ESSENTIAL_FIELD
#       components: 0
#       values: 14
#       func: FUNC_0_petsc_eqn_5
#     Weak Form System with 2 fields
#     Boundary Right[0] (Right) ESSENTIAL_FIELD
#       components: 0
#       values: 13
#       func: FUNC_0_petsc_eqn_5
#     Weak Form System with 2 fields
#   Field pressure FEM 1 component  (implicit) (Nq 6 Nqc 1) 1-jet
#     PetscFE Object: pressure (private__p_) 1 MPI process
#       type: basic
#       Basic Finite Element in 2 dimensions with 1 components
#       PetscSpace Object: P1 (private__p_) 1 MPI process
#         type: poly
#         Space in 2 variables with 1 components, size 3
#         Polynomial space of degree 1
#       PetscDualSpace Object: P1 (private__p_) 1 MPI process
#         type: lagrange
#         Dual space with 1 components, size 3
#         Continuous Lagrange dual space
#         Quadrature on a triangle of order 4 on 6 points (dim 2)
#   Weak Form System with 2 fields
#     residual_f0
# (0, 1) FUNC_0_petsc_eqn_2
# (0, 0) FUNC_0_petsc_eqn_0
#     residual_f1
# (0, 0) FUNC_0_petsc_eqn_1
#     jacobian_g0
# (0, 1) FUNC_0_petsc_eqn_14
# (1, 0) FUNC_0_petsc_eqn_14
# (0, 0) FUNC_0_petsc_eqn_11
#     jacobian_g1
# (0, 1) FUNC_0_petsc_eqn_11
# (1, 0) FUNC_0_petsc_eqn_15
# (0, 0) FUNC_0_petsc_eqn_7
#     jacobian_g2
# (0, 1) FUNC_0_petsc_eqn_12
# (0, 0) FUNC_0_petsc_eqn_13
#     jacobian_g3
# (0, 1) FUNC_0_petsc_eqn_13
# (0, 0) FUNC_0_petsc_eqn_9
#     jacobian_preconditioner_g0
# (0, 1) FUNC_0_petsc_eqn_14
# (1, 1) FUNC_0_petsc_eqn_16
# (1, 0) FUNC_0_petsc_eqn_14
# (0, 0) FUNC_0_petsc_eqn_11
#     jacobian_preconditioner_g1
# (0, 1) FUNC_0_petsc_eqn_11
# (1, 0) FUNC_0_petsc_eqn_15
# (0, 0) FUNC_0_petsc_eqn_7
#     jacobian_preconditioner_g2
# (0, 1) FUNC_0_petsc_eqn_12
# (0, 0) FUNC_0_petsc_eqn_13
#     jacobian_preconditioner_g3
# (0, 1) FUNC_0_petsc_eqn_13
# (0, 0) FUNC_0_petsc_eqn_9

# %%
for pen in [10, 33, 100, 330, 1000]:
    stokes.natural_bcs = []
    stokes.dm = None
    stokes.add_natural_bc((0.0, pen*u[1].sym), "Top")

    
    stokes.solve(zero_init_guess=False, _force_setup=True)
# Out:
# Stokes: Jacobians complete, now compile
# Setting bc 0 (natural)
#  - component: [0 1]
#  - boundary:   Top
#  - fn:         Matrix([[0], [10*\mathbf{u}_{ 1 }(N.x, N.y)]])
# Setting bc 0 (essential)
#  - component: [1]
#  - boundary:   Bottom
#  - fn:         Matrix([[oo], [0]])
# Setting bc 1 (essential)
#  - component: [0]
#  - boundary:   Left
#  - fn:         Matrix([[0], [oo]])
# Setting bc 2 (essential)
#  - component: [0]
#  - boundary:   Right
#  - fn:         Matrix([[0], [oo]])
#   0 SNES Function norm 5.817436137642e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 5.817436137642e-02
#     1 KSP Residual norm 4.644705720326e-06
#     2 KSP Residual norm 7.741462195277e-11
#   1 SNES Function norm 1.456187362015e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 1.456187362015e-02
#     1 KSP Residual norm 1.319167806290e-06
#     2 KSP Residual norm 4.816825473015e-11
#   2 SNES Function norm 3.646466410109e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 3.646466410109e-03
#     1 KSP Residual norm 2.810523330636e-07
#     2 KSP Residual norm 1.175636699157e-11
#   3 SNES Function norm 9.136597372768e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 9.136597372768e-04
#     1 KSP Residual norm 7.216595489451e-08
#     2 KSP Residual norm 2.333119524991e-12
#   4 SNES Function norm 2.290352309983e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 2.290352309983e-04
#     1 KSP Residual norm 1.257134062971e-08
#     2 KSP Residual norm 1.612083486949e-12
#   5 SNES Function norm 5.731834029003e-05
# Nonlinear  solve converged due to CONVERGED_FNORM_RELATIVE iterations 5
# Stokes: Jacobians complete, now compile
# Setting bc 0 (natural)
#  - component: [0 1]
#  - boundary:   Top
#  - fn:         Matrix([[0], [33*\mathbf{u}_{ 1 }(N.x, N.y)]])
# Setting bc 0 (essential)
#  - component: [1]
#  - boundary:   Bottom
#  - fn:         Matrix([[oo], [0]])
# Setting bc 1 (essential)
#  - component: [0]
#  - boundary:   Left
#  - fn:         Matrix([[0], [oo]])
# Setting bc 2 (essential)
#  - component: [0]
#  - boundary:   Right
#  - fn:         Matrix([[0], [oo]])
#   0 SNES Function norm 4.046377870185e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 4.046377870185e-02
#     1 KSP Residual norm 2.845009395468e-06
#     2 KSP Residual norm 1.086429394920e-10
#   1 SNES Function norm 1.574945238624e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 1.574945238624e-02
#     1 KSP Residual norm 9.984087140142e-07
#     2 KSP Residual norm 4.441074606031e-11
#   2 SNES Function norm 6.148428297117e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 6.148428297117e-03
#     1 KSP Residual norm 3.403045127117e-07
#     2 KSP Residual norm 1.783016621535e-11
#   3 SNES Function norm 2.424151168799e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 2.424151168799e-03
#     1 KSP Residual norm 1.274065453804e-07
#     2 KSP Residual norm 6.989015823562e-12
#   4 SNES Function norm 9.855534783914e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 9.855534783914e-04
#     1 KSP Residual norm 4.481554168579e-08
#     2 KSP Residual norm 6.044550568057e-12
#   5 SNES Function norm 4.347602520211e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 4.347602520211e-04
#     1 KSP Residual norm 2.685836255745e-08
#     2 KSP Residual norm 8.679987317699e-13
#   6 SNES Function norm 2.237334696385e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 2.237334696385e-04
#     1 KSP Residual norm 1.035440155268e-08
#     2 KSP Residual norm 4.311285882132e-13
#   7 SNES Function norm 1.363065359802e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.363065359802e-04
#     1 KSP Residual norm 7.073954450745e-09
#     2 KSP Residual norm 1.733578086147e-13
#   8 SNES Function norm 8.288891958076e-05
#     Residual norms for  solve.
#     0 KSP Residual norm 8.288891958076e-05
#     1 KSP Residual norm 3.044081611853e-09
#     2 KSP Residual norm 1.028288040801e-13
#   9 SNES Function norm 3.666735240024e-05
# Nonlinear  solve converged due to CONVERGED_FNORM_RELATIVE iterations 9
# Stokes: Jacobians complete, now compile
# Setting bc 0 (natural)
#  - component: [0 1]
#  - boundary:   Top
#  - fn:         Matrix([[0], [100*\mathbf{u}_{ 1 }(N.x, N.y)]])
# Setting bc 0 (essential)
#  - component: [1]
#  - boundary:   Bottom
#  - fn:         Matrix([[oo], [0]])
# Setting bc 1 (essential)
#  - component: [0]
#  - boundary:   Left
#  - fn:         Matrix([[0], [oo]])
# Setting bc 2 (essential)
#  - component: [0]
#  - boundary:   Right
#  - fn:         Matrix([[0], [oo]])
#   0 SNES Function norm 4.904742698125e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 4.904742698125e-02
#     1 KSP Residual norm 2.658147036937e-06
#     2 KSP Residual norm 9.355908739086e-11
#   1 SNES Function norm 3.184836916794e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 3.184836916794e-02
#     1 KSP Residual norm 1.966209623318e-06
#     2 KSP Residual norm 5.619679984475e-11
#   2 SNES Function norm 2.065358341122e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 2.065358341122e-02
#     1 KSP Residual norm 1.247174411769e-06
#     2 KSP Residual norm 4.146595312828e-11
#   3 SNES Function norm 1.341228783855e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 1.341228783855e-02
#     1 KSP Residual norm 8.146411334576e-07
#     2 KSP Residual norm 2.393277905429e-11
#   4 SNES Function norm 8.704338262598e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 8.704338262598e-03
#     1 KSP Residual norm 5.279026857962e-07
#     2 KSP Residual norm 1.713286381480e-11
#   5 SNES Function norm 5.650043922938e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 5.650043922938e-03
#     1 KSP Residual norm 3.427568447898e-07
#     2 KSP Residual norm 1.015727373117e-11
#   6 SNES Function norm 3.668423887520e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 3.668423887520e-03
#     1 KSP Residual norm 2.225790714275e-07
#     2 KSP Residual norm 7.136696413365e-12
#   7 SNES Function norm 2.380110115501e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 2.380110115501e-03
#     1 KSP Residual norm 1.443871249051e-07
#     2 KSP Residual norm 4.304298919130e-12
#   8 SNES Function norm 1.546190266036e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 1.546190266036e-03
#     1 KSP Residual norm 9.379377012583e-08
#     2 KSP Residual norm 2.981403827184e-12
#   9 SNES Function norm 1.002499393142e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 1.002499393142e-03
#     1 KSP Residual norm 6.083619690233e-08
#     2 KSP Residual norm 1.822680515655e-12
#  10 SNES Function norm 6.518328462347e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 6.518328462347e-04
#     1 KSP Residual norm 3.952190989983e-08
#     2 KSP Residual norm 1.247918358574e-12
#  11 SNES Function norm 4.221376983548e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 4.221376983548e-04
#     1 KSP Residual norm 2.563142774033e-08
#     2 KSP Residual norm 7.716257254775e-13
#  12 SNES Function norm 2.749015031740e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 2.749015031740e-04
#     1 KSP Residual norm 1.665625567908e-08
#     2 KSP Residual norm 5.230236235940e-13
#  13 SNES Function norm 1.776706226433e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.776706226433e-04
#     1 KSP Residual norm 1.079704436527e-08
#     2 KSP Residual norm 3.265532229600e-13
#  14 SNES Function norm 1.160165381765e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.160165381765e-04
#     1 KSP Residual norm 7.022684661334e-09
#     2 KSP Residual norm 2.194827406110e-13
#  15 SNES Function norm 7.471662433114e-05
#     Residual norms for  solve.
#     0 KSP Residual norm 7.471662433114e-05
#     1 KSP Residual norm 4.547320063532e-09
#     2 KSP Residual norm 1.381599513923e-13
#  16 SNES Function norm 4.902370223981e-05
# Nonlinear  solve converged due to CONVERGED_FNORM_RELATIVE iterations 16
# Stokes: Jacobians complete, now compile
# Setting bc 0 (natural)
#  - component: [0 1]
#  - boundary:   Top
#  - fn:         Matrix([[0], [330*\mathbf{u}_{ 1 }(N.x, N.y)]])
# Setting bc 0 (essential)
#  - component: [1]
#  - boundary:   Bottom
#  - fn:         Matrix([[oo], [0]])
# Setting bc 1 (essential)
#  - component: [0]
#  - boundary:   Left
#  - fn:         Matrix([[0], [oo]])
# Setting bc 2 (essential)
#  - component: [0]
#  - boundary:   Right
#  - fn:         Matrix([[0], [oo]])
#   0 SNES Function norm 6.258026698638e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 6.258026698638e-02
#     1 KSP Residual norm 2.704602829636e-06
#     2 KSP Residual norm 1.672702534512e-10
#   1 SNES Function norm 3.001665722916e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 3.001665722916e-02
#     1 KSP Residual norm 1.292034909516e-06
#     2 KSP Residual norm 6.455755610980e-11
#   2 SNES Function norm 1.444916871648e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 1.444916871648e-02
#     1 KSP Residual norm 6.504524743949e-07
#     2 KSP Residual norm 4.426652973845e-11
#   3 SNES Function norm 7.024911936750e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 7.024911936750e-03
#     1 KSP Residual norm 3.368155001757e-07
#     2 KSP Residual norm 4.054066463588e-11
#   4 SNES Function norm 3.505785709501e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 3.505785709501e-03
#     1 KSP Residual norm 1.210806940561e-07
#     2 KSP Residual norm 3.005189963596e-12
#   5 SNES Function norm 1.859212947798e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 1.859212947798e-03
#     1 KSP Residual norm 7.731951253761e-08
#     2 KSP Residual norm 1.495290261381e-12
#   6 SNES Function norm 1.100478308826e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 1.100478308826e-03
#     1 KSP Residual norm 4.476011557685e-08
#     2 KSP Residual norm 7.739794442567e-13
#   7 SNES Function norm 7.438137287349e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 7.438137287349e-04
#     1 KSP Residual norm 2.815882079417e-08
#     2 KSP Residual norm 1.490961340170e-12
#   8 SNES Function norm 5.564347704320e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 5.564347704320e-04
#     1 KSP Residual norm 1.823278057607e-08
#     2 KSP Residual norm 4.892575367235e-13
#   9 SNES Function norm 4.395533190313e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 4.395533190313e-04
#     1 KSP Residual norm 1.180826502004e-08
#     2 KSP Residual norm 5.691856480567e-13
#  10 SNES Function norm 2.415829783274e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 2.415829783274e-04
#     1 KSP Residual norm 2.852178448947e-09
#     2 KSP Residual norm 2.881017595990e-13
#  11 SNES Function norm 2.224898486152e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 2.224898486152e-04
#     1 KSP Residual norm 8.801976954835e-09
#     2 KSP Residual norm 1.620792597416e-13
#  12 SNES Function norm 1.645183663103e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.645183663103e-04
#     1 KSP Residual norm 4.830464005220e-09
#     2 KSP Residual norm 1.125397440895e-13
#  13 SNES Function norm 1.282730665654e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.282730665654e-04
#     1 KSP Residual norm 3.744873134750e-09
#     2 KSP Residual norm 1.008469401177e-13
#  14 SNES Function norm 7.177371810745e-05
#     Residual norms for  solve.
#     0 KSP Residual norm 7.177371810745e-05
#     1 KSP Residual norm 1.598574872278e-09
#     2 KSP Residual norm 6.565157226324e-14
#  15 SNES Function norm 6.694083451615e-05
#     Residual norms for  solve.
#     0 KSP Residual norm 6.694083451615e-05
#     1 KSP Residual norm 2.073006244707e-09
#     2 KSP Residual norm 9.673520972158e-14
#  16 SNES Function norm 5.253710457403e-05
# Nonlinear  solve converged due to CONVERGED_FNORM_RELATIVE iterations 16
# Stokes: Jacobians complete, now compile
# Setting bc 0 (natural)
#  - component: [0 1]
#  - boundary:   Top
#  - fn:         Matrix([[0], [1000*\mathbf{u}_{ 1 }(N.x, N.y)]])
# Setting bc 0 (essential)
#  - component: [1]
#  - boundary:   Bottom
#  - fn:         Matrix([[oo], [0]])
# Setting bc 1 (essential)
#  - component: [0]
#  - boundary:   Left
#  - fn:         Matrix([[0], [oo]])
# Setting bc 2 (essential)
#  - component: [0]
#  - boundary:   Right
#  - fn:         Matrix([[0], [oo]])
#   0 SNES Function norm 5.758854198960e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 5.758854198960e-02
#     1 KSP Residual norm 2.890770395669e-06
#     2 KSP Residual norm 1.873126721072e-10
#   1 SNES Function norm 3.220814541525e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 3.220814541525e-02
#     1 KSP Residual norm 1.746537478755e-06
#     2 KSP Residual norm 9.452645473646e-11
#   2 SNES Function norm 1.799432698686e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 1.799432698686e-02
#     1 KSP Residual norm 8.536141670267e-07
#     2 KSP Residual norm 6.867814317993e-11
#   3 SNES Function norm 1.005311358469e-02
#     Residual norms for  solve.
#     0 KSP Residual norm 1.005311358469e-02
#     1 KSP Residual norm 5.447329711836e-07
#     2 KSP Residual norm 2.824177674270e-11
#   4 SNES Function norm 5.635954115581e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 5.635954115581e-03
#     1 KSP Residual norm 4.013981643573e-07
#     2 KSP Residual norm 3.329411007171e-11
#   5 SNES Function norm 3.133146983570e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 3.133146983570e-03
#     1 KSP Residual norm 1.745717509600e-07
#     2 KSP Residual norm 9.038510519599e-12
#   6 SNES Function norm 1.772818973969e-03
#     Residual norms for  solve.
#     0 KSP Residual norm 1.772818973969e-03
#     1 KSP Residual norm 1.183166489812e-07
#     2 KSP Residual norm 1.094386453083e-11
#   7 SNES Function norm 9.718144517249e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 9.718144517249e-04
#     1 KSP Residual norm 5.754614063598e-08
#     2 KSP Residual norm 2.957955093843e-12
#   8 SNES Function norm 5.655498937800e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 5.655498937800e-04
#     1 KSP Residual norm 3.502757018771e-08
#     2 KSP Residual norm 3.915205216741e-12
#   9 SNES Function norm 2.988050037979e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 2.988050037979e-04
#     1 KSP Residual norm 1.978075588680e-08
#     2 KSP Residual norm 1.010226052927e-12
#  10 SNES Function norm 1.897883482469e-04
#     Residual norms for  solve.
#     0 KSP Residual norm 1.897883482469e-04
#     1 KSP Residual norm 1.111644703688e-08
#     2 KSP Residual norm 1.244615292609e-12
#  11 SNES Function norm 9.400703638371e-05
#     Residual norms for  solve.
#     0 KSP Residual norm 9.400703638371e-05
#     1 KSP Residual norm 7.174008388926e-09
#     2 KSP Residual norm 3.801736283441e-13
#  12 SNES Function norm 7.571051579352e-05
#     Residual norms for  solve.
#     0 KSP Residual norm 7.571051579352e-05
#     1 KSP Residual norm 4.278781199617e-09
#     2 KSP Residual norm 3.535715899078e-13
#  13 SNES Function norm 4.055350430962e-05
# Nonlinear  solve converged due to CONVERGED_FNORM_RELATIVE iterations 13

# %%
if uw.mpi.size == 1:

    import pyvista as pv
    import underworld3.visualisation as vis

    pvmesh = vis.mesh_to_pv_mesh(mesh)
    pvmesh.point_data["V"] = vis.vector_fn_to_pv_points(pvmesh, u.sym)
    pvmesh.point_data["P"] = vis.scalar_fn_to_pv_points(pvmesh, p.sym)
    velocity_points = vis.meshVariable_to_pv_cloud(u)
    velocity_points.point_data["V"] = vis.vector_fn_to_pv_points(velocity_points, u.sym)

    pl = pv.Plotter(window_size=[1000, 1000])
    pl.add_axes()

    pl.add_mesh(
        pvmesh,
        cmap="coolwarm",
        edge_color="Black",
        show_edges=True,
        scalars="P",
        use_transparency=False,
        opacity=1.0,
    )

    # pl.add_mesh(pvmesh, cmap="coolwarm", edge_color="Black", show_edges=True, scalars="T",
    #               use_transparency=False, opacity=1.0)

    # pl.add_arrows(pvmesh.points, pvmesh.point_data["V"], mag=10)
    pl.add_arrows(velocity_points.points, velocity_points.point_data["V"], mag=10)

    pl.show(cpos="xy")
# Out:
# Widget(value="<iframe src='http://localhost:52899/index.html?ui=P_0x17b7236d0_0&reconnect=auto' style='width: …

# %%
stokes.natural_bcs[0].fns["f0"] = "test"
